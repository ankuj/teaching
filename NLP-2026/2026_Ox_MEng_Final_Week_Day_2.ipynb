# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# ---
#
# ## Part 1: BERT and GPT Architectures
#
# ------------------------------<br>
# Task 1: BERT vs GPT — Theory<br>
# ------------------------------

# %%
def task1_bert_gpt():
    """
    Complete the comparison (write as comments):

    | Feature        | BERT              | GPT               |
    |----------------|-------------------|-------------------|
    | Architecture   | ?                 | ?                 |
    | Directionality | ?                 | ?                 |
    | Pre-training   | ?                 | ?                 |
    | Typical output | ?                 | ?                 |
    | Typical use    | ?                 | ?                 |

    Also answer:
    a) Why does GPT use causal masking?
    """
    # Your answer here:

    # --- Solution ---
    # a) Prevents attending to future tokens — preserves autoregressive generation at inference.

# %% [markdown]
# ------------------------------<br>
# Part 2: Pre-training Tasks — Theory<br>
# ------------------------------

# %%
def task2_pretraining_tasks():
    """
    Answer the following:

    a) Describe Masked Language Modeling (MLM) in one sentence.
    b) What was Next Sentence Prediction (NSP) designed to teach BERT?
    """
    # Your answer here:

    # --- Solution ---
    # a)
    # b) Whether two sentences naturally follow each other — sentence-pair relationships.

# %% [markdown]
# ---
#
# ## Part 3: Positional Encoding
#
# Transformers have no inherent order — positional encodings are **added** to input embeddings:
#
# $$PE(pos, 2i) = \sin\!\left(\frac{pos}{10000^{2i/d_{model}}}\right), \quad PE(pos, 2i+1) = \cos\!\left(\frac{pos}{10000^{2i/d_{model}}}\right)$$

# %% [markdown]
# ------------------------------<br>
# Task 3: Implement Sinusoidal Positional Encoding<br>
# ------------------------------
#
# Return a matrix of shape `(max_len, d_model)` using the sinusoidal formula. Even embedding indices use sin; odd indices use cos.

# %%
import numpy as np

def sinusoidal_positional_encoding(max_len, d_model):
    """
    Return PE matrix of shape (max_len, d_model) using the sinusoidal formula.
    Even indices: sin, odd indices: cos.
    """
    # Your code here:



X = np.ndarray([0.1, 0.2, 0.3, 0.4]) # single token of dimension 4, at position 0
pe = sinusoidal_positional_encoding(X)

# %% [markdown]
# ---
#
# ## Part 4: Tokenization - Theory

# %%
def task8_tokenization_theory():
    """
    Answer the following:

    a) Compare character-level, word-level, and subword-level tokenization (one pro/con each).
    b) Why can the same sentence cost 3×–15× more tokens in some languages?
    """
    # Your answer here:

    # --- Solution ---
    # a) Char: handles OOV but long sequences; Word: intuitive but huge vocab/OOV;
    #    Subword: balance — BPE/SentencePiece handle rare words via pieces.
    # b)

# %% [markdown]
# ---
#
# ## Part 5: Future Directions
#
# ------------------------------<br>

# %%
def task12_future():
    """
    Answer the following:

    a) Name three future directions for LLMs from the lecture.
    b) Why are smaller efficient LLMs (distillation, quantization) an active research area?
    c) What is the key takeaway about tokenizer design and training data?
    d) In one sentence: why are LLMs expensive, and why do design choices (tokenization, scale) matter?
    """
    # Your answer here:

    # --- Solution ---
    # a) Long-context handling, token-free/byte models, multimodal LLMs, smaller efficient models,
    #    open-weight ethical LLMs (any three).
    # b)
    # c) Tokenizer and training corpus must stay in sync; unfair tokenization creates imbalance across languages.
    # d)
